# %% [markdown]
# <a href="https://colab.research.google.com/github/khoa030602/AI31-03-23/blob/main/31_3_23(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar10
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
import matplotlib.pyplot as plt
# Out:
# ...
# 170498071/170498071 [==============================] - 6s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_test.shape
# Out:
# (10000, 1)

# %%
for i in range(10):
  plt.subplot(3,5,i+1)
  plt.tight_layout
  plt.imshow(x_train[i],cmap='gray',interpolation='None')
  plt.title('nay la:{}'.format(y_train[i]))
  plt.xticks
  plt.yticks

# %%
from keras.models import Sequential #mang ANN
from keras.layers import Dense #ket noi
model=Sequential()
model.add(Dense(512,activation='relu',input_shape=(32*32*3,)))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 512)               1573376
#
#  dense_1 (Dense)             (None, 10)                5130
#
# ...
# Total params: 1,578,506
# Trainable params: 1,578,506
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train=x_train.reshape((50000,32*32*3))
x_train=x_train.astype('float32')/255

x_train.shape
# Out:
# (50000, 3072)

# %%
x_test=x_test.reshape((10000,32*32*3))
x_test=x_test.astype('float32')/255
x_test.shape
# Out:
# (10000, 3072)

# %%
from keras.utils import to_categorical
y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)

# %%
y_train.shape
# Out:
# (50000, 10)

# %%
y_test.shape
# Out:
# (10000, 10)

# %%
model.compile(optimizer='rmsprop', loss= 'categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=100, batch_size=10000)
test_loss, test_acc = model.evaluate(x_test, y_test)
print('do chinh xac:', test_loss)
print('do chinh xac:', test_acc)
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 6s 1s/step - loss: 1.3846 - accuracy: 0.5599
# Epoch 2/1000
# 5/5 [==============================] - 7s 1s/step - loss: 0.9437 - accuracy: 0.6726
# Epoch 3/1000
# 5/5 [==============================] - 6s 1s/step - loss: 0.9441 - accuracy: 0.6714
# Epoch 4/1000
# 2/5 [===========>..................] - ETA: 5s - loss: 0.9493 - accuracy: 0.6726

# %%
model.save('test1.h5')

# %%
img = plt.imread('/content/meo.jpg')
plt.imshow(img)
plt.show()

# %%
import numpy as np
from keras.utils.image_utils import img_to_array
from keras.utils import load_img
img = load_img('/content/meo.jpg', target_size= (32,32))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,32*32*3)
img = img.astype('float32')
img = img/255
np.argmax(model.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 76ms/step
# array([3])

# %%
img = plt.imread('/content/271816034-1080283546160341-5548642910824517215-n-1642490383.jpg')
plt.imshow(img)
plt.show()

# %%
import numpy as np
from keras.utils.image_utils import img_to_array
from keras.utils import load_img
img = load_img('/content/271816034-1080283546160341-5548642910824517215-n-1642490383.jpg', target_size= (32,32))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,32*32*3)
img = img.astype('float32')
img = img/255
np.argmax(model.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 51ms/step
# array([7])
